# %%
import geopandas as gpd

df = gpd.read_file(r'C:\Users\jg198\Desktop\Italy-sites')
df.head()
# Out:
#      osm_id                  name              type                   geometry
# 0  24985802                  None            castle  POINT (14.88117 41.16618)
# 1  32644147           Foro Romano  archaeological_s  POINT (12.48667 41.88985)
# 2  32648080    Castel Sant’Angelo            castle  POINT (12.46642 41.90306)
# 3  32650148           Foro Boario  archaeological_s  POINT (12.48100 41.88890)
# 4  36257633  Castello di Miramare            castle  POINT (13.71230 45.70261)

# %%
df = df.set_geometry('geometry')

df.shape
# Out:
# (326, 4)

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1,1, figsize=(15, 15))
df.plot(ax=ax)
# Out:
# <AxesSubplot: >

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 15))
df.plot(ax=ax, column='type', legend=True, cmap='viridis')
# Out:
# <AxesSubplot: >

# %%
import matplotlib.pyplot as plt

data = {'archaeological_s': 59, 'castle': 140, 'ruins': 127}
names = list(data.keys())
values = list(data.values())

fig, axs = plt.subplots(1, 3, figsize=(9, 3), sharey=True)
axs[0].bar(names, values)
axs[1].scatter(names, values)
axs[2].plot(names, values)
fig.suptitle('Categorical Plotting')
# Out:
# Text(0.5, 0.98, 'Categorical Plotting')
