# %%
import os.path
from PIL import Image
Image.open('/Users/jg198/Desktop/Emoji.jpg')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=513x511>

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

import os.path

import os.path
from PIL import Image
Image.open('/Users/jg198/Desktop/Emoji.jpg')

fig, ax = plt.subplots()
im = ax.imshow(image)
patch = patches.Circle((260, 200), radius=200, transform=ax.transData)
im.set_clip_path(patch)

ax.axis('off')
plt.show()
