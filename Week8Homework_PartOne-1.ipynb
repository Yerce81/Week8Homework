# %%
import matplotlib.pyplot as plt

# %%
RegionalCraftBrewery = [178, 186, 202, 230, 240, 220, 223]
Microbreweries = [2684, 3319, 3956, 4518, 1917, 1898, 1886]
Taprooms = [0, 0, 0, 0, 3091, 3471, 3708]
Brewpubs = [1941, 2208, 2503, 2870, 3171, 3302, 3307]
LargeNonCraft = [44, 67, 106, 104, 111, 120, 129]
year = ["2015", "2016", "2017", "2018", "2019", "2020", "2021"]

fig, ax = plt.subplots()
ax.plot(year, RegionalCraftBrewery, label="RegionalCraftBrewery")
ax.plot(year, Microbreweries, label="Microbreweries")
ax.plot(year, Taprooms, label="Taprooms")
ax.plot(year, Brewpubs, label="Brewpubs")
ax.plot(year, LargeNonCraft, label="LargeNonCraft")
ax.legend()

plt.show()
